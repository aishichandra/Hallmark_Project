# %%
import requests
import pandas as pd
import numpy as np
import datetime
from bs4 import BeautifulSoup

# %% [markdown]
# ### Data Collection

# %% [markdown]
# Every Single Hallmark Movie is Listed on Wikipedia across several pages. 2000-2015 is in one URL and all the years after 2015 has a indiv address with the year changing in the url

# %%
# collecting the data for 2000-2015

response = requests.get('https://en.wikipedia.org/wiki/List_of_Hallmark_Channel_Original_Movies_(2000%E2%80%932015)#2000')
doc = BeautifulSoup(response.text)

# %%
df_list = []
for i in range(1,22):
    url = 'https://en.wikipedia.org/wiki/List_of_Hallmark_Channel_Original_Movies_(2000%E2%80%932015)#2000'
    df_list.append(pd.read_html(url)[i])

df_2015 = pd.concat(df_list)
df_2015
# Out:
#     No.                                             Movie  \
# 0   1.0                                 A Storm in Summer
# 1   2.0                Arabian Nights (2-part miniseries)
# 2   3.0         Personally Yours (a.k.a. Wilderness Love)
# 3   4.0                    The Hound of the Baskervilles†
# 4   5.0  The Christmas Secret (a.k.a. Flight of Reindeer)
# ..  ...                                               ...
# 37  NaN        Karen Kingsbury's The Bridge: Part 1 (CtC)
# 38  NaN             On the Twelfth Day of Christmas (CtC)
# 39  NaN                          A Christmas Melody (CtC)
# 40  NaN                              Christmas Land (CtC)
# 41  NaN       When Calls the Heart: New Year's Wish (CtC)
#
#                                             Starring          Director  \
# 0   Peter Falk, Andrew McCarthy and Nastassja Kinski       Robert Wise
# 1                    Mili Avital and Jason Scott Lee      Steve Barron
# 2            Valerie Bertinelli and Jeffrey Nordling    Jeffrey Reiner
# 3                      Matt Frewer and Kenneth Welsh    Rodney Gibbons
# 4                    Beau Bridges and Richard Thomas         Ian Barry
# ..                                               ...               ...
# 37                      Katie Findlay and Wyatt Nash         Mike Rohl
# 38                      Brooke Nevin and Robin Dunne  Harvey Crossland
# 39  Lacey Chabert, Brennan Elliott, and Mariah Carey      Mariah Carey
# 40                 Nikki Deloach and Luke Macfarlane         Sam Irvin
# 41    Erin Krakow, Daniel Lissing, and Lori Loughlin    Neill Fearnley
#
#      Original airdate  Viewers    Ref  DVD
# 0   February 27, 2000      NaN    NaN  NaN
# 1      April 30, 2000      NaN    NaN  NaN
# 2     October 8, 2000      NaN    NaN  NaN
# 3    October 21, 2000      NaN    [3]  NaN
# 4   December 17, 2000      NaN    NaN  NaN
# ..                ...      ...    ...  ...
# 37   December 6, 2015     3.20  [317]  NaN
# 38  December 12, 2015     3.51  [318]  NaN
# 39  December 19, 2015     3.95  [319]  NaN
# 40  December 20, 2015     4.24  [320]  NaN
# 41  December 26, 2015     2.49  [321]  NaN
#
# [392 rows x 8 columns]

# %%
#Now doing the same thing for all the other years

# %%
df_list = []
for i in range(6,20):
    url = "https://en.wikipedia.org/wiki/List_of_Hallmark_Channel_Original_Movies#2022"
    df_list.append(pd.read_html(url)[i])

df_2022 = pd.concat(df_list)
df_2022
# Out:
#                          Movie  \
# 0         Love in Paradise (W)
# 1       Love's Complicated (W)
# 2    Love on the Sidelines (W)
# 3     Unleashing Mr. Darcy (W)
# 4      Dater's Handbook (CtVD)
# ..                         ...
# 32      Fly Away With Me (FiL)
# 33        Girlfriendship (FiL)
# 34    Pumpkin Everything (FiL)
# 35    Autumn in the City (FiL)
# 36  Jolly Good Christmas (CtC)
#
#                                              Starring               Director  \
# 0                   Emmanuelle Vaugier and Luke Perry          Sean McNamara
# 1                      Holly Marie Combs and Ben Bass       Jerry Ciccoritti
# 2                       Emily Kinney and John Reardon           Terry Ingram
# 3                         Cindy Busby and Ryan Paevey          David Winning
# 4   Meghan Markle, Kristoffer Polaha, and Jonathan...             James Head
# ..                                                ...                    ...
# 32                      Natalie Hall and Peter Mooney    Marita Jane Grabiak
# 33  Tamera Mowry-Housley, Lyndie Greenwood, Krysta...  Keshia Knight Pulliam
# 34                       Taylor Cole and Corey Sevier           Jeff Beesley
# 35                  Aimee Teegarden and Evan Roderick                    NaN
# 36                        Reshma Shetty and Will Kemp        Jonathan Wright
#
#       Original airdate  Viewers   Ref  DVD
# 0      January 2, 2016     3.07  [24]  NaN
# 1      January 9, 2016     2.23  [25]  NaN
# 2     January 16, 2016     2.40  [26]  NaN
# 3     January 23, 2016     3.04  [27]  NaN
# 4     January 30, 2016     1.99  [28]  NaN
# ..                 ...      ...   ...  ...
# 32  September 24, 2022      NaN   NaN  NaN
# 33     October 1, 2022      NaN   NaN  NaN
# 34     October 8, 2022      NaN   NaN  NaN
# 35    October 15, 2022      NaN   NaN  NaN
# 36    October 22, 2022      NaN   NaN  NaN
#
# [576 rows x 7 columns]

# %%
# concat these two tables together
frames = [df_2015, df_2022]
df_movies = pd.concat(frames)
df_movies
# Out:
#     No.                                             Movie  \
# 0   1.0                                 A Storm in Summer
# 1   2.0                Arabian Nights (2-part miniseries)
# 2   3.0         Personally Yours (a.k.a. Wilderness Love)
# 3   4.0                    The Hound of the Baskervilles†
# 4   5.0  The Christmas Secret (a.k.a. Flight of Reindeer)
# ..  ...                                               ...
# 32  NaN                            Fly Away With Me (FiL)
# 33  NaN                              Girlfriendship (FiL)
# 34  NaN                          Pumpkin Everything (FiL)
# 35  NaN                          Autumn in the City (FiL)
# 36  NaN                        Jolly Good Christmas (CtC)
#
#                                              Starring               Director  \
# 0    Peter Falk, Andrew McCarthy and Nastassja Kinski            Robert Wise
# 1                     Mili Avital and Jason Scott Lee           Steve Barron
# 2             Valerie Bertinelli and Jeffrey Nordling         Jeffrey Reiner
# 3                       Matt Frewer and Kenneth Welsh         Rodney Gibbons
# 4                     Beau Bridges and Richard Thomas              Ian Barry
# ..                                                ...                    ...
# 32                      Natalie Hall and Peter Mooney    Marita Jane Grabiak
# 33  Tamera Mowry-Housley, Lyndie Greenwood, Krysta...  Keshia Knight Pulliam
# 34                       Taylor Cole and Corey Sevier           Jeff Beesley
# 35                  Aimee Teegarden and Evan Roderick                    NaN
# 36                        Reshma Shetty and Will Kemp        Jonathan Wright
#
#       Original airdate  Viewers  Ref  DVD
# 0    February 27, 2000      NaN  NaN  NaN
# 1       April 30, 2000      NaN  NaN  NaN
# 2      October 8, 2000      NaN  NaN  NaN
# 3     October 21, 2000      NaN  [3]  NaN
# 4    December 17, 2000      NaN  NaN  NaN
# ..                 ...      ...  ...  ...
# 32  September 24, 2022      NaN  NaN  NaN
# 33     October 1, 2022      NaN  NaN  NaN
# 34     October 8, 2022      NaN  NaN  NaN
# 35    October 15, 2022      NaN  NaN  NaN
# 36    October 22, 2022      NaN  NaN  NaN
#
# [968 rows x 8 columns]

# %%
df_movies = df_movies.drop(['No.', 'DVD', 'Viewers','Ref'], axis=1)

# %%
df_movies[df_movies['Movie'] == 'The Monkey King (a.k.a. The Lost Empire)']
# Out:
#                                       Movie  \
# 1  The Monkey King (a.k.a. The Lost Empire)
#
#                                     Starring         Director Original airdate
# 1  Thomas Gibson, Bai Ling, and Russell Wong  Peter MacDonald   March 11, 2001

# %%
#Im noticing that some of these movies are a part of seasonal programming block -> create a column for each one
# NYNM New Year New Movies!
# L Loveuary
# SiL Spring into Love,
# SN Summer Nights
# CiJ Christmas in July
# FiL Fall into Love,
# CtC Countdown to Christmas
df_movies['seasonal_blocks'] = df_movies['Movie'].str.split('(').str[1].str.replace(")", "")
df_movies
# Out:
# C:\Users\aisvarya\AppData\Local\Temp\ipykernel_15776\3527166068.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_movies['seasonal_blocks'] = df_movies['Movie'].str.split('(').str[1].str.replace(")", "")
#                                                Movie  \
# 0                                  A Storm in Summer
# 1                 Arabian Nights (2-part miniseries)
# 2          Personally Yours (a.k.a. Wilderness Love)
# 3                     The Hound of the Baskervilles†
# 4   The Christmas Secret (a.k.a. Flight of Reindeer)
# ..                                               ...
# 32                            Fly Away With Me (FiL)
# 33                              Girlfriendship (FiL)
# 34                          Pumpkin Everything (FiL)
# 35                          Autumn in the City (FiL)
# 36                        Jolly Good Christmas (CtC)
#
#                                              Starring               Director  \
# 0   [Peter Falk,  Andrew McCarthy,  Nastassja Kinski]            Robert Wise
# 1                     [Mili Avital,  Jason Scott Lee]           Steve Barron
# 2             [Valerie Bertinelli,  Jeffrey Nordling]         Jeffrey Reiner
# 3                       [Matt Frewer,  Kenneth Welsh]         Rodney Gibbons
# 4                     [Beau Bridges,  Richard Thomas]              Ian Barry
# ..                                                ...                    ...
# 32                      [Natalie Hall,  Peter Mooney]    Marita Jane Grabiak
# 33  [Tamera Mowry-Housley,  Lyndie Greenwood,  Kry...  Keshia Knight Pulliam
# 34                       [Taylor Cole,  Corey Sevier]           Jeff Beesley
# 35                  [Aimee Teegarden,  Evan Roderick]                    NaN
# 36                        [Reshma Shetty,  Will Kemp]        Jonathan Wright
#
#       Original airdate            seasonal_blocks
# 0    February 27, 2000                        NaN
# 1       April 30, 2000          2-part miniseries
# 2      October 8, 2000     a.k.a. Wilderness Love
# 3     October 21, 2000                        NaN
# 4    December 17, 2000  a.k.a. Flight of Reindeer
# ..                 ...                        ...
# 32  September 24, 2022                        FiL
# 33     October 1, 2022                        FiL
# 34     October 8, 2022                        FiL
# 35    October 15, 2022                        FiL
# 36    October 22, 2022                        CtC
#
# [968 rows x 5 columns]

# %%
df_movies['Starring'] = df_movies['Starring'].str.replace(', and', ',').str.replace(' and', ',').str.split(',')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [191], in <cell line: 1>()
# ----> 1 df_movies['Starring'] = df_movies['Starring'].str.replace(', and', ',').str.replace(' and', ',').str.split(',')
#
# File ~\scoop\apps\pyenv\current\pyenv-win\versions\3.10.3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\scoop\apps\pyenv\current\pyenv-win\versions\3.10.3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\scoop\apps\pyenv\current\pyenv-win\versions\3.10.3\lib\site-packages\pandas\core\strings\accessor.py:177, in StringMethods.__init__(self, data)
#     174 def __init__(self, data):
#     175     from pandas.core.arrays.string_ import StringDtype
# --> 177     self._inferred_dtype = self._validate(data)
#     178     self._is_categorical = is_categorical_dtype(data.dtype)
#     179     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\scoop\apps\pyenv\current\pyenv-win\versions\3.10.3\lib\site-packages\pandas\core\strings\accessor.py:231, in StringMethods._validate(data)
#     228 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     230 if inferred_dtype not in allowed_types:
# --> 231     raise AttributeError("Can only use .str accessor with string values!")
#     232 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
actor_df = df_movies.explode('Starring')

# %%
actor_df.Starring = actor_df.Starring.str.strip()

# %%
actor_df
# Out:
#                                  Movie          Starring         Director  \
# 0                    A Storm in Summer        Peter Falk      Robert Wise
# 0                    A Storm in Summer   Andrew McCarthy      Robert Wise
# 0                    A Storm in Summer  Nastassja Kinski      Robert Wise
# 1   Arabian Nights (2-part miniseries)       Mili Avital     Steve Barron
# 1   Arabian Nights (2-part miniseries)   Jason Scott Lee     Steve Barron
# ..                                 ...               ...              ...
# 34            Pumpkin Everything (FiL)      Corey Sevier     Jeff Beesley
# 35            Autumn in the City (FiL)   Aimee Teegarden              NaN
# 35            Autumn in the City (FiL)     Evan Roderick              NaN
# 36          Jolly Good Christmas (CtC)     Reshma Shetty  Jonathan Wright
# 36          Jolly Good Christmas (CtC)         Will Kemp  Jonathan Wright
#
#      Original airdate    seasonal_blocks
# 0   February 27, 2000                NaN
# 0   February 27, 2000                NaN
# 0   February 27, 2000                NaN
# 1      April 30, 2000  2-part miniseries
# 1      April 30, 2000  2-part miniseries
# ..                ...                ...
# 34    October 8, 2022                FiL
# 35   October 15, 2022                FiL
# 35   October 15, 2022                FiL
# 36   October 22, 2022                CtC
# 36   October 22, 2022                CtC
#
# [2107 rows x 5 columns]

# %%
top_actors = actor_df.Starring.value_counts().reset_index(name = 'count').rename(columns={'index' :'actor'}).head(10)['actor'].to_list()
top_actors
# Out:
# ['Lacey Chabert',
#  'Candace Cameron Bure',
#  'Kellie Martin',
#  'Brennan Elliott',
#  'Lori Loughlin',
#  'Niall Matter',
#  'Taylor Cole',
#  'Alison Sweeney',
#  'Jill Wagner',
#  'Andrew Walker']

# %%
#What was the time span for each of these actors? - when did they start appearing and when did they stop?
actor_df['year'] = actor_df['Original airdate'].str[-4:]

# %%
# actor_df['Original airdate']
actor_df
# Out:
#                                  Movie          Starring         Director  \
# 0                    A Storm in Summer        Peter Falk      Robert Wise
# 0                    A Storm in Summer   Andrew McCarthy      Robert Wise
# 0                    A Storm in Summer  Nastassja Kinski      Robert Wise
# 1   Arabian Nights (2-part miniseries)       Mili Avital     Steve Barron
# 1   Arabian Nights (2-part miniseries)   Jason Scott Lee     Steve Barron
# ..                                 ...               ...              ...
# 34            Pumpkin Everything (FiL)      Corey Sevier     Jeff Beesley
# 35            Autumn in the City (FiL)   Aimee Teegarden              NaN
# 35            Autumn in the City (FiL)     Evan Roderick              NaN
# 36          Jolly Good Christmas (CtC)     Reshma Shetty  Jonathan Wright
# 36          Jolly Good Christmas (CtC)         Will Kemp  Jonathan Wright
#
#      Original airdate    seasonal_blocks  year
# 0   February 27, 2000                NaN  2000
# 0   February 27, 2000                NaN  2000
# 0   February 27, 2000                NaN  2000
# 1      April 30, 2000  2-part miniseries  2000
# 1      April 30, 2000  2-part miniseries  2000
# ..                ...                ...   ...
# 34    October 8, 2022                FiL  2022
# 35   October 15, 2022                FiL  2022
# 35   October 15, 2022                FiL  2022
# 36   October 22, 2022                CtC  2022
# 36   October 22, 2022                CtC  2022
#
# [2107 rows x 6 columns]

# %%
actor_df['year'] = actor_df['year'].astype(str).astype(int)

# %%
actor_df[actor_df['Starring'].isin(top_actors)].head(60)
# Out:
#                                                 Movie              Starring  \
# 7                                       Mystery Woman         Kellie Martin
# 0                      Mystery Woman: Mystery Weekend         Kellie Martin
# 4                             Mystery Woman: Snapshot         Kellie Martin
# 8                     Mystery Woman: Sing Me a Murder         Kellie Martin
# 15                  Mystery Woman: Vision of a Murder         Kellie Martin
# 23                           Mystery Woman: Game Time         Kellie Martin
# 2                       Mystery Woman: At First Sight         Kellie Martin
# 7                     Mystery Woman: Wild West Murder         Kellie Martin
# 16                             Mystery Woman: Oh Baby         Kellie Martin
# 19                          Mystery Woman: Redemption         Kellie Martin
# 1                       Mystery Woman: In the Shadows         Kellie Martin
# 16                            Moonlight and Mistletoe  Candace Cameron Bure
# 0                                   The Nanny Express       Brennan Elliott
# 2                                       Elevator Girl         Lacey Chabert
# 5         A Soldier's Love Story (a.k.a. Meet My Mom)         Lori Loughlin
# 3                                              Smooch         Kellie Martin
# 8                                          Puppy Love  Candace Cameron Bure
# 9                                      I Married Who?         Kellie Martin
# 15                             Matchmaker Santa (CtC)         Lacey Chabert
# 20                        A Bride for Christmas (CtC)         Andrew Walker
# 9                                      Second Chances        Alison Sweeney
# 13                                Garage Sale Mystery         Lori Loughlin
# 16                               When Calls the Heart         Lori Loughlin
# 23                       The Christmas Ornament (CtC)         Kellie Martin
# 27                                  Let It Snow (CtC)  Candace Cameron Bure
# 21                            A Royal Christmas (CtC)         Lacey Chabert
# 23                        Christmas Under Wraps (CtC)  Candace Cameron Bure
# 2                                   The Color of Rain         Lacey Chabert
# 5                             Wedding Planner Mystery         Andrew Walker
# 6              Garage Sale Mystery: All That Glitters         Lori Loughlin
# 2                                         Bridal Wave         Andrew Walker
# 7                              So You Said Yes (CtVD)         Kellie Martin
# 9                              All of My Heart (CtVD)         Lacey Chabert
# 9                              All of My Heart (CtVD)       Brennan Elliott
# 12                               Just the Way You Are  Candace Cameron Bure
# 16                               Family for Christmas         Lacey Chabert
# 18                                    Love on the Air        Alison Sweeney
# 19                                 Autumn Dreams (FH)           Jill Wagner
# 29                Northpole: Open for Christmas (CtC)         Lori Loughlin
# 34                           A Christmas Detour (CtC)  Candace Cameron Bure
# 39                           A Christmas Melody (CtC)         Lacey Chabert
# 39                           A Christmas Melody (CtC)       Brennan Elliott
# 41        When Calls the Heart: New Year's Wish (CtC)         Lori Loughlin
# 6                            Appetite for Love (CtVD)           Taylor Cole
# 6                            Appetite for Love (CtVD)         Andrew Walker
# 13                                     Date with Love         Andrew Walker
# 16                             Stop the Wedding! (JW)          Niall Matter
# 22                              My Summer Prince (SN)           Taylor Cole
# 30                         A Wish for Christmas (CtC)         Lacey Chabert
# 32                  Every Christmas Has a Story (CtC)         Lori Loughlin
# 33                            Christmas Cookies (CtC)           Jill Wagner
# 37                       Christmas in Homestead (CtC)           Taylor Cole
# 40                    Journey Back to Christmas (CtC)  Candace Cameron Bure
# 41                         A Dream of Christmas (CtC)         Andrew Walker
# 44                      Love You Like Christmas (CtC)       Brennan Elliott
# 47               When Calls the Heart Christmas (CtC)         Lori Loughlin
# 0   Garage Sale Mystery: Guilty Until Proven Innocent         Lori Loughlin
# 1          Murder, She Baked: A Peach Cobbler Mystery        Alison Sweeney
# 2                 Flower Shop Mystery: Mum's the Word       Brennan Elliott
# 7             Flower Shop Mystery: Snipped in the Bud       Brennan Elliott
#
#                   Director    Original airdate     seasonal_blocks  year
# 7          Walter Klenhard     August 31, 2003                 NaN  2003
# 0           Mark Griffiths     January 7, 2005                 NaN  2005
# 4     Georg Stanford Brown    January 28, 2005                 NaN  2005
# 8   Stephen W. Bridgewater   February 25, 2005                 NaN  2005
# 15           Kellie Martin        June 5, 2005                 NaN  2005
# 23       David S. Cass Sr.     August 21, 2005                 NaN  2005
# 2            Kellie Martin    January 21, 2006                 NaN  2006
# 7        David S. Cass Sr.      March 18, 2006                 NaN  2006
# 16       David S. Cass Sr.     August 19, 2006                 NaN  2006
# 19       David S. Cass Sr.    November 6, 2006                 NaN  2006
# 1        David S. Cass Sr.    January 13, 2007                 NaN  2007
# 16            Karen Arthur   November 29, 2008                 NaN  2008
# 0             Bradford May     January 3, 2009                 NaN  2009
# 2             Bradford May   February 13, 2010                 NaN  2010
# 5             Harvey Frost         May 8, 2010  a.k.a. Meet My Mom  2010
# 3               Ron Oliver    February 5, 2011                 NaN  2011
# 8             Harvey Frost   September 8, 2012                 NaN  2012
# 9             Kevin Connor    October 20, 2012                 NaN  2012
# 15       David S. Cass Sr.   November 17, 2012                 CtC  2012
# 20              Gary Yates    December 1, 2012                 CtC  2012
# 9          Ernie Barbarash       July 27, 2013                 NaN  2013
# 13           Peter DeLuise  September 14, 2013                 NaN  2013
# 16      Michael Landon Jr.    October 19, 2013                 NaN  2013
# 23               Mark Jean   November 16, 2013                 CtC  2013
# 27            Harvey Frost   November 30, 2013                 CtC  2013
# 21               Alex Zamm   November 21, 2014                 CtC  2014
# 23          Peter Sullivan   November 29, 2014                 CtC  2014
# 2             Anne Wheeler        May 31, 2014                 NaN  2014
# 5               Ron Oliver    October 19, 2014                 NaN  2014
# 6            Peter DeLuise    October 26, 2014                 NaN  2014
# 2         Michael M. Scott    January 17, 2015                 NaN  2015
# 7       Christie Will Wolf    February 7, 2015                CtVD  2015
# 9            Peter DeLuise   February 14, 2015                CtVD  2015
# 9            Peter DeLuise   February 14, 2015                CtVD  2015
# 12          K.T. Donaldson         May 9, 2015                 NaN  2015
# 16          Amanda Tapping       July 11, 2015                 NaN  2015
# 18          K.T. Donaldson  September 26, 2015                 NaN  2015
# 19          Neill Fearnley     October 3, 2015                  FH  2015
# 29            Douglas Barr   November 21, 2015                 CtC  2015
# 34              Ron Oliver   November 28, 2015                 CtC  2015
# 39            Mariah Carey   December 19, 2015                 CtC  2015
# 39            Mariah Carey   December 19, 2015                 CtC  2015
# 41          Neill Fearnley   December 26, 2015                 CtC  2015
# 6             David Mackay    February 6, 2016                CtVD  2016
# 6             David Mackay    February 6, 2016                CtVD  2016
# 13              Ron Oliver        May 21, 2016                 NaN  2016
# 16            Anne Wheeler       June 11, 2016                  JW  2016
# 22          Peter Sullivan      August 6, 2016                  SN  2016
# 30      Christie Will Wolf    October 29, 2016                 CtC  2016
# 32              Ron Oliver   November 12, 2016                 CtC  2016
# 33              James Head   November 13, 2016                 CtC  2016
# 37        Steven R. Monroe   November 24, 2016                 CtC  2016
# 40              Mel Damski   November 27, 2016                 CtC  2016
# 41              Gary Yates    December 3, 2016                 CtC  2016
# 44         Graeme Campbell   December 11, 2016                 CtC  2016
# 47          Neill Fearnley   December 25, 2016                 CtC  2016
# 0            Peter DeLuise     January 3, 2016                 NaN  2016
# 1           K.T. Donaldson    January 10, 2016                 NaN  2016
# 2            Bradley Walsh    January 17, 2016                 NaN  2016
# 7            Bradley Walsh      April 24, 2016                 NaN  2016

# %%
import altair as alt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [203], in <cell line: 1>()
# ----> 1 import altair as alt
#
# ModuleNotFoundError: No module named 'altair'
